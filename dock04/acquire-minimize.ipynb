# %% [markdown]
# # Acquire and Minimize

# %% [markdown]
# ## Configuration

# %%
#inputeliganddir = "preprocessed/Ideal_Ligand/"
outputminimizeddir = "preprocessed/minimized_ideal_ligand/"
pubchemdir = "preprocessed/pubchem/"

# %% [markdown]
# ## Download Pubchem files by CAS number

# %%
import pandas as pd
import pubchempy as pcp

# Input CSV must have a column named 'CAS'
df = pd.read_csv(pubchemdir + "cas.csv")

results = []

for cas in df["CAS"].dropna():
    cas = str(cas).strip()
    try:
        compounds = pcp.get_compounds(cas, namespace="name")
        if compounds:
            c = compounds[0]
            results.append({
                "CAS": cas,
                "CID": c.cid,
                "MolecularFormula": c.molecular_formula,
                "MolecularWeight": c.molecular_weight,
                "IUPACName": c.iupac_name
            })
        else:
            results.append({
                "CAS": cas,
                "CID": None,
                "MolecularFormula": None,
                "MolecularWeight": None,
                "IUPACName": None
            })
    except Exception as e:
        results.append({
            "CAS": cas,
            "CID": None,
            "MolecularFormula": None,
            "MolecularWeight": None,
            "IUPACName": f"ERROR: {e}"
        })

out = pd.DataFrame(results)
out.to_csv(pubchemdir + "pubchem_lookup_results.csv", index=False)

# %%
import csv

# Path to your CSV file
csv_file = pubchemdir + "pubchem_lookup_results.csv"

# Read single-column CSV into a Python list
cas_list = []

with open(csv_file, newline='', encoding='utf-8') as f:
    reader = csv.reader(f)

    for row in reader:
        if row:                 # skip empty rows
            cas_list.append(row[0])

print(cas_list)
# Out:
# ['CAS', '57-63-6', '84-16-2', '56-53-1', '84-17-3', '53-16-7', '72-33-3', '57-91-0', '50-27-1', '50-28-2', '34816-55-2', '474-86-2', '5976-61-4', '53-63-4', '362-05-0', '120-47-8', '72-55-9', '72-43-5', '53-19-0', '59-50-7', '207-13-4', '1570-64-5', '72-54-8', '97-54-1', '85-68-7', '90-43-7', '99-76-3', '92-69-3', '140-10-3', '131-57-7', '115-29-7', '115-86-6', '123-07-9', '84-69-5']

# %%
import pubchempy as pcp

if cas_list and cas_list[0] == 'CAS':
    cas_list.pop(0)
print(cas_list)

#cas_list = ["120-47-8","72-55-9","72-43-5"]

for cas in cas_list:
    matches = pcp.get_compounds(cas, namespace="name")
    if matches:
        cid = matches[0].cid
        out = pubchemdir + "cas-" + cas + ".sdf"
        print ("Download and write " + out)
        pcp.download("SDF", out, cid, namespace='cid', overwrite=True, record_type='3d')
    else:
        print("No match found for " + cas + ". Sorry. :(")
# Out:
# ['57-63-6', '84-16-2', '56-53-1', '84-17-3', '53-16-7', '72-33-3', '57-91-0', '50-27-1', '50-28-2', '34816-55-2', '474-86-2', '5976-61-4', '53-63-4', '362-05-0', '120-47-8', '72-55-9', '72-43-5', '53-19-0', '59-50-7', '207-13-4', '1570-64-5', '72-54-8', '97-54-1', '85-68-7', '90-43-7', '99-76-3', '92-69-3', '140-10-3', '131-57-7', '115-29-7', '115-86-6', '123-07-9', '84-69-5']
# Download and write preprocessed/pubchem/cas-57-63-6.sdf
# Download and write preprocessed/pubchem/cas-84-16-2.sdf
# Download and write preprocessed/pubchem/cas-56-53-1.sdf
# Download and write preprocessed/pubchem/cas-84-17-3.sdf
# Download and write preprocessed/pubchem/cas-53-16-7.sdf
# Download and write preprocessed/pubchem/cas-72-33-3.sdf
# Download and write preprocessed/pubchem/cas-57-91-0.sdf
# Download and write preprocessed/pubchem/cas-50-27-1.sdf
# Download and write preprocessed/pubchem/cas-50-28-2.sdf
# Download and write preprocessed/pubchem/cas-34816-55-2.sdf
# Download and write preprocessed/pubchem/cas-474-86-2.sdf
# Download and write preprocessed/pubchem/cas-5976-61-4.sdf
# Download and write preprocessed/pubchem/cas-53-63-4.sdf
# Download and write preprocessed/pubchem/cas-362-05-0.sdf
# Download and write preprocessed/pubchem/cas-120-47-8.sdf
# Download and write preprocessed/pubchem/cas-72-55-9.sdf
# Download and write preprocessed/pubchem/cas-72-43-5.sdf
# Download and write preprocessed/pubchem/cas-53-19-0.sdf
# Download and write preprocessed/pubchem/cas-59-50-7.sdf
# No match found for 207-13-4. Sorry. :(
# Download and write preprocessed/pubchem/cas-1570-64-5.sdf
# Download and write preprocessed/pubchem/cas-72-54-8.sdf
# Download and write preprocessed/pubchem/cas-97-54-1.sdf
# Download and write preprocessed/pubchem/cas-85-68-7.sdf
# Download and write preprocessed/pubchem/cas-90-43-7.sdf
# Download and write preprocessed/pubchem/cas-99-76-3.sdf
# Download and write preprocessed/pubchem/cas-92-69-3.sdf
# Download and write preprocessed/pubchem/cas-140-10-3.sdf
# Download and write preprocessed/pubchem/cas-131-57-7.sdf
# Download and write preprocessed/pubchem/cas-115-29-7.sdf
# Download and write preprocessed/pubchem/cas-115-86-6.sdf
# Download and write preprocessed/pubchem/cas-123-07-9.sdf
# Download and write preprocessed/pubchem/cas-84-69-5.sdf

# %% [markdown]
# ## Download missed files

# %%
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/record/SDF?record_type=3d&response_type=save&response_basename=Conformer3D_COMPOUND_CID_75575
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/record/SDF?record_type=3d&response_type=save&response_basename=Conformer3D_COMPOUND_CID_75575
#url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/record/SDF?record_type=3d&response_type=save&response_basename=Conformer3D_COMPOUND_CID_75575"

# %%
#localfile = pubchemdir + "207-13-4.sdf"
#!wget -O {localfile} {url}

# %%
# This works.
# Need to use the Webpage to identify the CID number.
# wget -O 207-13-4_3d.sdf https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/SDF?record_type=3d

# !wget -O preprocessed/pubchem/cas-207-13-4.sdf https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/SDF?record_type=3d
# Out:
# --2026-05-14 11:05:10--  https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/CID/75575/SDF?record_type=3d
# Resolving pubchem.ncbi.nlm.nih.gov (pubchem.ncbi.nlm.nih.gov)... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to pubchem.ncbi.nlm.nih.gov (pubchem.ncbi.nlm.nih.gov)|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [chemical/x-mdl-sdfile]
# Saving to: ‘preprocessed/pubchem/207-13-4.sdf’
#
# preprocessed/pubche     [ <=>                ]   4.86K  --.-KB/s    in 0s
#
# 2026-05-14 11:05:10 (443 MB/s) - ‘preprocessed/pubchem/207-13-4.sdf’ saved [4975]

# %% [markdown]
# ## Minimize the SDF files

# %%
# samples from Maya. This code based on  mfaber_workflow/workflow_notebook/Ligand_Prep_Trial.ipynb

# For a single file
# !obabel EST.sdf -O minEST.sdf -p --minimize --ff mmff94

#!for f in Ideal_Ligand/*.sdf; do \
#  base=$(basename "$f" .sdf); \
#  obabel "$f" -O "minimized_ideal_ligand/${base}_min.sdf" -p --minimize --ff mmff94; \
#done

# %%
import os

for entry in os.scandir(pubchemdir):
    if entry.is_file() and entry.name.endswith(".sdf"):
        
        stem = os.path.splitext(entry.name)[0]
        out = outputminimizeddir + stem + "_min.sdf"
        print("Convert " + entry.path + " to " + out)
        # !obabel "{entry.path}" -O "{out}" -p --minimize --ff mmff94
# Out:
# Convert preprocessed/pubchem/cas-56-53-1.sdf to preprocessed/minimized_ideal_ligand/cas-56-53-1_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-92-69-3.sdf to preprocessed/minimized_ideal_ligand/cas-92-69-3_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-97-54-1.sdf to preprocessed/minimized_ideal_ligand/cas-97-54-1_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-140-10-3.sdf to preprocessed/minimized_ideal_ligand/cas-140-10-3_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-123-07-9.sdf to preprocessed/minimized_ideal_ligand/cas-123-07-9_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-99-76-3.sdf to preprocessed/minimized_ideal_ligand/cas-99-76-3_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-474-86-2.sdf to preprocessed/minimized_ideal_ligand/cas-474-86-2_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-115-29-7.sdf to preprocessed/minimized_ideal_ligand/cas-115-29-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-53-63-4.sdf to preprocessed/minimized_ideal_ligand/cas-53-63-4_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-131-57-7.sdf to preprocessed/minimized_ideal_ligand/cas-131-57-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-90-43-7.sdf to preprocessed/minimized_ideal_ligand/cas-90-43-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-53-16-7.sdf to preprocessed/minimized_ideal_ligand/cas-53-16-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-57-63-6.sdf to preprocessed/minimized_ideal_ligand/cas-57-63-6_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-84-17-3.sdf to preprocessed/minimized_ideal_ligand/cas-84-17-3_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-59-50-7.sdf to preprocessed/minimized_ideal_ligand/cas-59-50-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-115-86-6.sdf to preprocessed/minimized_ideal_ligand/cas-115-86-6_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-72-55-9.sdf to preprocessed/minimized_ideal_ligand/cas-72-55-9_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-207-13-4.sdf to preprocessed/minimized_ideal_ligand/cas-207-13-4_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-5976-61-4.sdf to preprocessed/minimized_ideal_ligand/cas-5976-61-4_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-50-27-1.sdf to preprocessed/minimized_ideal_ligand/cas-50-27-1_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-362-05-0.sdf to preprocessed/minimized_ideal_ligand/cas-362-05-0_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-72-54-8.sdf to preprocessed/minimized_ideal_ligand/cas-72-54-8_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-84-69-5.sdf to preprocessed/minimized_ideal_ligand/cas-84-69-5_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-34816-55-2.sdf to preprocessed/minimized_ideal_ligand/cas-34816-55-2_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-84-16-2.sdf to preprocessed/minimized_ideal_ligand/cas-84-16-2_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-50-28-2.sdf to preprocessed/minimized_ideal_ligand/cas-50-28-2_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-57-91-0.sdf to preprocessed/minimized_ideal_ligand/cas-57-91-0_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-120-47-8.sdf to preprocessed/minimized_ideal_ligand/cas-120-47-8_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-1570-64-5.sdf to preprocessed/minimized_ideal_ligand/cas-1570-64-5_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-72-43-5.sdf to preprocessed/minimized_ideal_ligand/cas-72-43-5_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-85-68-7.sdf to preprocessed/minimized_ideal_ligand/cas-85-68-7_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-72-33-3.sdf to preprocessed/minimized_ideal_ligand/cas-72-33-3_min.sdf
# 1 molecule converted
# Convert preprocessed/pubchem/cas-53-19-0.sdf to preprocessed/minimized_ideal_ligand/cas-53-19-0_min.sdf
# 1 molecule converted
